# %%
from mass_sims import mass_test_cnn_models
# Out:
# Now Training One Layer Models
# Training model: conv_config=(1, 6, 3, 1, 1, 1)
# Epoch 1, Loss: 0.647
# Accuracy: 89.93%
# Epoch 2, Loss: 0.320
# Accuracy: 91.60%
# Epoch 3, Loss: 0.269
# Accuracy: 92.70%
# Epoch 4, Loss: 0.230
# Accuracy: 94.13%
# Epoch 5, Loss: 0.200
# Accuracy: 94.83%
# Finished Training
# Testing model...
# Average test loss: 0.1772, Accuracy: 9525/10000 (95.25%)
# Training model: conv_config=(1, 18, 3, 1, 1, 1)
# Epoch 1, Loss: 0.527
# Accuracy: 91.22%
# Epoch 2, Loss: 0.265
# Accuracy: 93.36%
# Epoch 3, Loss: 0.209
# Accuracy: 94.81%
# Epoch 4, Loss: 0.173
# Accuracy: 95.76%
# Epoch 5, Loss: 0.146
# Accuracy: 96.30%
# Finished Training
# Testing model...
# Average test loss: 0.1268, Accuracy: 9640/10000 (96.40%)
# Now Training Two Layer Models
# Training model: conv_config=(1, 3, 3, 1, 1, 1, 3, 3, 1, 1, 1)
# Epoch 1, Loss: 1.056
# Accuracy: 89.77%
# Epoch 2, Loss: 0.275
# Accuracy: 92.93%
# Epoch 3, Loss: 0.207
# Accuracy: 94.14%
# Epoch 4, Loss: 0.173
# ...

# %%
# Out:
# [(1, 2, 3, 1, 1, 1, 1, 2, 3, 1, 1, 1, 1, 2, 3, 1, 1, 1), (1, 6, 3, 1, 1, 1, 1, 6, 3, 1, 1, 1, 1, 6, 3, 1, 1, 1)]
