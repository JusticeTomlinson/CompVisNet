# %%
from mass_sims import mass_test_cnn_models
# Out:
# Now Training One Layer Models
# Training model: conv_config=(1, 3, 3, 1, 1, 1)
# Epoch 1, Loss: 0.807, Accuracy: 80.61%
# Epoch 2, Loss: 0.310, Accuracy: 91.13%
# Epoch 3, Loss: 0.251, Accuracy: 92.92%
# Epoch 4, Loss: 0.216, Accuracy: 93.89%
# Epoch 5, Loss: 0.192, Accuracy: 94.56%
# Finished Training
# Testing model...
# Average test loss: 0.1724, Accuracy: 9509/10000 (95.09%)
# Training model: conv_config=(1, 6, 3, 1, 1, 1)
# Epoch 1, Loss: 0.663, Accuracy: 81.89%
# Epoch 2, Loss: 0.298, Accuracy: 91.17%
# Epoch 3, Loss: 0.236, Accuracy: 93.24%
# Epoch 4, Loss: 0.196, Accuracy: 94.43%
# Epoch 5, Loss: 0.166, Accuracy: 95.31%
# Finished Training
# Testing model...
# Average test loss: 0.1403, Accuracy: 9610/10000 (96.10%)
# Training model: conv_config=(1, 12, 3, 1, 1, 1)
# Epoch 1, Loss: 0.530, Accuracy: 85.06%
# Epoch 2, Loss: 0.286, Accuracy: 91.61%
# Epoch 3, Loss: 0.231, Accuracy: 93.40%
# Epoch 4, Loss: 0.194, Accuracy: 94.46%
# Epoch 5, Loss: 0.167, Accuracy: 95.34%
# ...

# %%
# Out:
# [(1, 2, 3, 1, 1, 1, 1, 2, 3, 1, 1, 1, 1, 2, 3, 1, 1, 1), (1, 6, 3, 1, 1, 1, 1, 6, 3, 1, 1, 1, 1, 6, 3, 1, 1, 1)]
